# %%
import riot_api_functions as riot

summoners = riot.get_summoners_data_by_division('DIAMOND', 'I')
print(len(summoners[0]))
print(summoners[0])
# Out:
# 8183
# ...

# %%
x = riot.get_summoners_data()
print(x)
